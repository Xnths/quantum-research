# %%
# Let B[1..n] be a binary number with n being the total digits we need to guess.
## We don't know B and we have a function f(b, j, x) (working as a black box)
### It returns true if the b[j] == x

# %%
from qiskit import *
# %matplotlib inline
from qiskit.tools.visualization import plot_histogram

secretnumber = '101001'

circuit = QuantumCircuit(7, 6)

circuit.h([0, 1, 2, 3, 4, 5,])
circuit.x(6)
circuit.h(6)
circuit.barrier()

# %%
circuit.draw(output='mpl')
